# %%
# !python "visualizer_training.py" \
  --bert_model "indobenchmark/indobert-base-p2" \
  --model_path "checkpoint/fold2/model_best" \
  --data_path "data/govapp/fold2"

# %%
# !python "visualizer_validation.py" \
  --bert_model "indobenchmark/indobert-base-p2" \
  --model_path "checkpoint/fold2/model_best" \
  --data_path "data/govapp/fold2"
# Out:
# Using device: cuda
#
# [1] Loading tokenizer: indobenchmark/indobert-base-p2
#
# [2] Creating data processor with max_seq_len=128
#
# [3] Loading dataset from data/govapp/fold2
#   Dataset loaded with 564 examples
#
# [4] Building SPAN-ASTE model
#   Target dimension (SpanLabel): 3 - ['INVALID', 'ASPECT', 'OPINION']
#   Relation dimension (RelationLabel): 4 - ['INVALID', 'POS', 'NEG', 'NEU']
#
# [5] Loading model weights from checkpoint/fold2/model_best/model.pt
#
# [6] Processing example data to visualize model steps
#
# ================================================================================
# EXAMPLE 1:
# ================================================================================
#
# [6.1] Input Text:
#   Example 1: "[CLS] mohon untuk admin nya . tolong itu dicek lagi . setiap kali buka aplikasi nya selalu tidak dapat terkoneksi ke server . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]"
#
#   Gold Spans (ground truth):
#     Span 1: (14, 15) -> "aplikasi nya" (Type: ASPECT)
#     Span 2: (17, 23) -> "tidak dapat terkoneksi ke server . [SEP]" (Type: OPINION)
#
#   Gold Relations (ground truth triplets):
#     Triplet 1: (14,15,17,23) -> Aspect: "aplikasi nya", Opinion: "tidak dapat terkoneksi ke server . [SEP]", Sentiment: NEG
#
# [6.2] BERT Encoder Processing:
#   BERT output shape: torch.Size([1, 128, 768])
#   This represents contextualized embeddings for each token in the input sequence
#
# [6.3] Span Representation Generation:
#   Generated 164 possible spans with representation dimension 1556
#   Each span is represented as [hi; hj; f_width(i,j)] where:
#     - hi is the BERT embedding of the start token
#     - hj is the BERT embedding of the end token
#     - f_width(i,j) is a learned embedding of the span width
#
#   Example spans:
#     Span 1: (0,0) -> "[CLS]" (width: 1)
#     Span 2: (1,1) -> "mohon" (width: 1)
#     Span 3: (2,2) -> "untuk" (width: 1)
#     Span 4: (3,3) -> "admin" (width: 1)
#     Span 5: (4,4) -> "nya" (width: 1)
#     ... (total spans: 164)
#
# [6.4] Span Classification (FFNN):
#   Span probability tensor shape: torch.Size([1, 164, 3])
#   Each span is classified into one of 3 categories:
#     0: INVALID
#     1: ASPECT
#     2: OPINION
#
#   Top predicted spans:
#
#     Top ASPECT spans:
#       1: (14,15) -> "aplikasi nya" (prob: 1.0000)
#       2: (21,23) -> "server . [SEP]" (prob: 0.9957)
#       3: (3,4) -> "admin nya" (prob: 0.1336)
#
#     Top OPINION spans:
#       1: (17,20) -> "tidak dapat terkoneksi ke" (prob: 0.9968)
#       2: (3,4) -> "admin nya" (prob: 0.0003)
#       3: (8,11) -> "dicek lagi . setiap" (prob: 0.0001)
#
# [6.5] Span Pruning:
#   Pruning spans based on probability threshold 0.5
#   This step reduces computational complexity by selecting only high-probability spans
#   Keeping top 12 aspect and opinion spans
#   Target indices tensor shape: torch.Size([1, 12])
#   Opinion indices tensor shape: torch.Size([1, 12])
#
#   Top pruned aspect spans:
#     1: (14,15) -> "aplikasi nya" (prob: 1.0000)
#     2: (21,23) -> "server . [SEP]" (prob: 0.9957)
#     3: (3,4) -> "admin nya" (prob: 0.1336)
#
#   Top pruned opinion spans:
#     1: (17,20) -> "tidak dapat terkoneksi ke" (prob: 0.9968)
#     2: (3,4) -> "admin nya" (prob: 0.0003)
#     3: (8,11) -> "dicek lagi . setiap" (prob: 0.0001)
#
# [6.6] Target-Opinion Pair Representation:
#   Candidate representation tensor shape: torch.Size([1, 144, 3240])
#   Each candidate pair is represented as [St; So; f_distance(St,So)] where:
#     - St is the representation of the target span
#     - So is the representation of the opinion span
#     - f_distance(St,So) is a learned embedding of the distance between spans
#
#   Example candidate pairs:
#     Pair 1: (14,15,17,20)
#       Aspect: "aplikasi nya"
#       Opinion: "tidak dapat terkoneksi ke"
#       Min distance: 2 tokens
#     Pair 2: (14,15,3,4)
#       Aspect: "aplikasi nya"
#       Opinion: "admin nya"
#       Min distance: 10 tokens
#     Pair 3: (14,15,8,11)
#       Aspect: "aplikasi nya"
#       Opinion: "dicek lagi . setiap"
#       Min distance: 3 tokens
#     Pair 4: (14,15,21,23)
#       Aspect: "aplikasi nya"
#       Opinion: "server . [SEP]"
#       Min distance: 6 tokens
#     Pair 5: (14,15,20,23)
#       Aspect: "aplikasi nya"
#       Opinion: "ke server . [SEP]"
#       Min distance: 5 tokens
#     ... (total candidate pairs: 144)
#
# [6.7] Relation Classification (FFNN):
#   Relation probability tensor shape: torch.Size([1, 144, 4])
#   Each relation is classified into one of 4 categories:
#     0: INVALID
#     1: POS
#     2: NEG
#     3: NEU
#
#   Top predicted sentiment triplets:
#     Triplet 1:
#       Aspect: "server . [SEP]"
#       Opinion: "tidak dapat terkoneksi ke"
#       Sentiment: NEG (prob: 0.8138)
#     Triplet 2:
#       Aspect: "aplikasi nya"
#       Opinion: "tidak dapat terkoneksi ke"
#       Sentiment: NEG (prob: 0.4477)
#     Triplet 3:
#       Aspect: "admin nya"
#       Opinion: "dicek lagi . setiap"
#       Sentiment: NEG (prob: 0.0001)
#     Triplet 4:
#       Aspect: "aplikasi nya"
#       Opinion: "dicek lagi . setiap"
#       Sentiment: NEG (prob: 0.0000)
#     Triplet 5:
#       Aspect: "admin nya"
#       Opinion: "tidak dapat terkoneksi ke"
#       Sentiment: NEG (prob: 0.0000)
#
# ================================================================================
# PROCESSING COMPLETED FOR EXAMPLE 1
# ================================================================================
