# %% [markdown]
# ## **Install Library**

# %% [markdown]
# *Folder berisi source code arsitektur Span-Level ASTE berbasis PyTorch*

# %% [markdown]
# ## **Fine Tuning Model**

# %% [markdown]
# **Per Epoch**

# %% [markdown]
# ### **Fold 1**

# %% [markdown]
# Pake data yang udah di prepro

# %%
# !python "train_epoch.py" \
--bert_model "indobenchmark/indobert-large-p2" \
--batch_size 4 \
--learning_rate 2e-5 \
--weight_decay 1e-2 \
--warmup_proportion 0.1 \
--train_path "data/govapp_pre/fold1" \
--dev_path "data/govapp_pre/fold1" \
--save_dir "checkpoint_large/fold1" \
--max_seq_len 512 \
--num_epochs 30 \
--visualize \
--viz_dir "visualization_large/fold1/" \
--viz_filename "visualisasi.png"
# Out:
# using device:cuda
# Loading Train & Eval Dataset...
# Construct Dataloader...
# Building SPAN-ASTE model...
# Building Optimizer...
#
# === Starting Training ===
#
# Epoch 1/30: 100%|██████████████████████████████| 579/579 [09:18<00:00,  1.04it/s
#
# Epoch 1 completed in 558.91s. Average loss: 287.56886
#
# ...
# Validation at end of epoch 1
# Evaluation metrics:
#   Precision: 0.00000
#   Recall: 0.00000
#   F1: 0.00000
#   Validation Loss: 44.81856
# ...
#
# Epoch 2/30: 100%|██████████████████████████████| 579/579 [09:29<00:00,  1.02it/s
#
# Epoch 2 completed in 569.89s. Average loss: 36.27646
#
# ...
# Validation at end of epoch 2
# Evaluation metrics:
#   Precision: 1.00000
#   Recall: 0.00503
#   F1: 0.01001
#   Validation Loss: 27.61601
#
# ✨ Best F1 score improved: 0.00000 --> 0.01001
# ...
#
# Epoch 3/30: 100%|██████████████████████████████| 579/579 [09:32<00:00,  1.01it/s
#
# Epoch 3 completed in 572.43s. Average loss: 29.65822
#
# ...
# Validation at end of epoch 3
# Evaluation metrics:
# ...

# %% [markdown]
# ### **Fold 2**

# %%
# !python "train_epoch.py" \
--bert_model "indobenchmark/indobert-large-p2" \
--batch_size 4 \
--learning_rate 2e-5 \
--weight_decay 1e-2 \
--warmup_proportion 0.1 \
--train_path "data/govapp_pre/fold2" \
--dev_path "data/govapp_pre/fold2" \
--save_dir "checkpoint_large/fold2" \
--max_seq_len 512 \
--num_epochs 30 \
--visualize \
--viz_dir "visualization_large/fold2/" \
--viz_filename "visualisasi.png"
# Out:
# using device:cuda
# Loading Train & Eval Dataset...
# Construct Dataloader...
# Building SPAN-ASTE model...
# Building Optimizer...
#
# === Starting Training ===
#
# Epoch 1/30: 100%|██████████████████████████████| 579/579 [14:59<00:00,  1.55s/it
#
# Epoch 1 completed in 899.43s. Average loss: 263.85102
#
# ...
# Validation at end of epoch 1
# Evaluation metrics:
#   Precision: 0.00000
#   Recall: 0.00000
#   F1: 0.00000
#   Validation Loss: 49.56152
# ...
#
# Epoch 2/30: 100%|██████████████████████████████| 579/579 [14:45<00:00,  1.53s/it
#
# Epoch 2 completed in 885.81s. Average loss: 36.58238
#
# ...
# Validation at end of epoch 2
# Evaluation metrics:
#   Precision: 0.78261
#   Recall: 0.02118
#   F1: 0.04124
#   Validation Loss: 30.14283
#
# ✨ Best F1 score improved: 0.00000 --> 0.04124
# ...
#
# Epoch 3/30: 100%|██████████████████████████████| 579/579 [15:06<00:00,  1.57s/it
#
# Epoch 3 completed in 906.28s. Average loss: 29.30522
#
# ...
# Validation at end of epoch 3
# Evaluation metrics:
# ...

# %% [markdown]
# ### **Fold 3**

# %%
# !python "train_epoch.py" \
--bert_model "indobenchmark/indobert-base-p2" \
--batch_size 1 \
--learning_rate 5e-5 \
--weight_decay 1e-2 \
--warmup_proportion 0.1 \
--train_path "data/govapp_pre/fold3" \
--dev_path "data/govapp_pre/fold3" \
--save_dir "checkpoint/prepro/fold3" \
--max_seq_len 512 \
--num_epochs 30 \
--visualize \
--viz_dir "visualization/prepro/fold3/" \
--viz_filename "visualisasi.png"

# %% [markdown]
# ### **Fold 4**

# %%
# !python "train_epoch.py" \
--bert_model "indobenchmark/indobert-base-p2" \
--batch_size 1 \
--learning_rate 5e-5 \
--weight_decay 1e-2 \
--warmup_proportion 0.1 \
--train_path "data/govapp_pre/fold4" \
--dev_path "data/govapp_pre/fold4" \
--save_dir "checkpoint/prepro/fold4" \
--max_seq_len 512 \
--num_epochs 30
--visualize \
--viz_dir "visualization/prepro/fold4/" \
--viz_filename "visualisasi.png"

# %% [markdown]
# ### **Fold 5**

# %%
# !python "train_epoch.py" \
--bert_model "indobenchmark/indobert-base-p2" \
--batch_size 1 \
--learning_rate 5e-5 \
--weight_decay 1e-2 \
--warmup_proportion 0.1 \
--train_path "data/govapp_pre/fold5" \
--dev_path "data/govapp_pre/fold5" \
--save_dir "checkpoint/prepro/fold5" \
--max_seq_len 512 \
--num_epochs 30
--visualize \
--viz_dir "visualization/prepro/fold5/" \
--viz_filename "visualisasi.png"

# %% [markdown]
# ## **Testing**

# %%
# !python "test.py" --model_path "checkpoint/model_best" --test_path "data/govapp" --output_path "triplet_output/train.xlsx"
# Out:
# Using device: cuda
# Loading tokenizer from indobenchmark/indobert-base-p2
# Building SPAN-ASTE model...
# Loading model from checkpoint/model_best
# Processing test data from data/govapp/dev_triplets.txt
# Text: apps nya bagus untuk daftar vaksin booster, untuk yg mendaftar vaksin lebih diutamakan jika menggunakan jaki krn menyesuaikan dgn jadwal free kita. cukup isi profil, (kalau untuk validitas data tunggu 2 hari) lalu cari menu vaksinasi lalu isi nik, nama, alamat, dan no tlp, lalu pilih puskes/rs, pilih tgl tanggal. setelah selesai lanjut isi pre-screening, setelah selesai cetak hasilnya. td saya vaksin dos 3 hanya 10 menit sudah selesai dan langsung terintegrasi app peduli lindungi..
# Predict: [('apps nya', 'bagus untuk', 'POS')]
# Label: [('apps', 'bagus', 'POS')]
# --------------------------------------------------------------------------------
# Text: ini gimana sih apk resmi bpom malah sering error trus scan barcode selalu gabisa.
# ...

# %% [markdown]
# ### **Fold 2**

# %%
# !python "test.py" --model_path "checkpoint/fold2/model_best" --test_path "data/govapp/fold2" --output_path "triplet_output/fold2/train.xlsx"
# Out:
# Using device: cuda
# Loading tokenizer from indobenchmark/indobert-base-p2
# Building SPAN-ASTE model...
# Loading model from checkpoint/fold2/model_best
# Processing test data from data/govapp/fold2/dev_triplets.txt
# Text: mohon untuk admin nya. tolong itu dicek lagi. setiap kali buka aplikasi nya selalu tidak dapat terkoneksi ke server.
# Predict: [('server . [SEP]', 'tidak dapat terkoneksi ke', 'NEG')]
# Label: [('aplikasi', 'tidak dapat terkoneksi ke server.', 'NEG')]
# --------------------------------------------------------------------------------
# Text: app. susah dipakai.. mau lapor video susah.
# Predict: [('lapor video susah', 'susah . [SEP]', 'NEG')]
# Label: [('app.', 'susah dipakai..', 'NEG'), ('lapor video', 'susah.', 'NEG')]
# --------------------------------------------------------------------------------
# Text: aplikasi gak jelas. pencarian informasi produk lelet banget.
# ...

# %% [markdown]
# ### **Fold 3**

# %%
# !python "test.py" --model_path "checkpoint/fold3/model_best" --test_path "data/govapp/fold3" --output_path "triplet_output/fold3/train.xlsx"
# Out:
# Using device: cuda
# Loading tokenizer from indobenchmark/indobert-base-p2
# Building SPAN-ASTE model...
# Loading model from checkpoint/fold3/model_best
# Processing test data from data/govapp/fold3/dev_triplets.txt
# Text: bikin surat kelahiran, ribet. sudah di isi semua file juga berhasil di upload, tapi tak kunjung ada konfirmasi & penyelesaian, email pun tak dpat balasan dr sipraja, uninstal dech.
# Predict: []
# Label: [('upload,', 'berhasil', 'POS'), ('email', 'tak dpat balasan', 'NEG')]
# --------------------------------------------------------------------------------
# Text: kenapa tidak bisa mengganti foto profil.
# Predict: [('mengganti foto profil . [SEP]', 'tidak bisa mengganti', 'NEG')]
# Label: [('foto profil.', 'tidak bisa mengganti', 'NEG')]
# --------------------------------------------------------------------------------
# Text: alhamdulillah pengajuan berkas lancar dan cepat.
# ...

# %% [markdown]
# ### **Fold 4**

# %%
# !python "test.py" --model_path "checkpoint/fold4/model_best" --test_path "data/govapp/fold4" --output_path "triplet_output/fold4/train.xlsx"
# Out:
# Using device: cuda
# Loading tokenizer from indobenchmark/indobert-base-p2
# Building SPAN-ASTE model...
# Loading model from checkpoint/fold4/model_best
# Processing test data from data/govapp/fold4/dev_triplets.txt
# Text: maaf ini aplikasi kenapa yaa? waktu awal saya menggunakan aplikasi ini semuanya bagus dan lancar. tapi setelah update malah jadi jelek begini. masa saya cek bpom produk cosmetic awalnya muncul beberapa nomor bpom dari tiap item produknya , setelah di coba ke dua kalinya malah katanya produk tidak terdaftar, padahal pertama dicek semua nomor bpom produknya muncul. tolong diperbaiki lagi, kalau sudah membaik baru saya kasih bintang 5.
# Predict: [('update malah', 'jelek begini', 'NEG'), ('aplikasi ini', 'bagus dan', 'POS')]
# Label: [('aplikasi', 'bagus', 'POS'), ('aplikasi', 'lancar.', 'POS'), ('update', 'jelek', 'NEG')]
# --------------------------------------------------------------------------------
# Text: apk ga bisa digunain, developernya gmn si.
# ...

# %% [markdown]
# ### **Fold 5**

# %%
# !python "test.py" --model_path "checkpoint/fold5/model_best" --test_path "data/govapp/fold5" --output_path "triplet_output/fold5/train.xlsx"

# %% [markdown]
# ## **Evaluate**

# %% [markdown]
# ### **Fold 1**

# %% [markdown]
# On Validation Data

# %%
# !python "evaluate.py" \
--test_path  "data/govapp_pre/fold1" \
--bert_model "indobenchmark/indobert-large-p1" \
--model_path "checkpoint_large/fold1/model_best" \
--batch_size 1 \
--max_seq_len 512
# Out:
# using device:cuda
# Loading Train & Eval Dataset...
# Construct Dataloader...
# Building SPAN-ASTE model...
# -----------------------------
# Evaluation Precision: 0.67417 | Recall: 0.64676 | F1: 0.66018

# %% [markdown]
# On Test Data

# %%
# !python "evaluate_test.py" \
--test_path  "data/govapp_pre/fold1" \
--bert_model "indobenchmark/indobert-large-p1" \
--model_path "checkpoint_large/fold1/model_best" \
--batch_size 1 \
--max_seq_len 512
# Out:
# using device:cuda
# Loading Train & Eval Dataset...
# Construct Dataloader...
# Building SPAN-ASTE model...
# -----------------------------
# Evaluation Precision: 0.68502 | Recall: 0.63366 | F1: 0.65834

# %% [markdown]
# ### **Fold 2**

# %% [markdown]
# On Validation Data

# %%
# !python "evaluate.py" \
--test_path  "data/govapp/fold2" \
--bert_model "indobenchmark/indobert-base-p2" \
--model_path "checkpoint/fold2/model_best" \
--batch_size 1 \
--max_seq_len 512

# %% [markdown]
# On Test Data

# %%
# !python "evaluate_test.py" \
--test_path  "data/govapp/fold2" \
--bert_model "indobenchmark/indobert-base-p2" \
--model_path "checkpoint/fold2/model_best" \
--batch_size 1 \
--max_seq_len 512

# %% [markdown]
# ### **Fold 3**

# %%
# !python "evaluate.py" \
--test_path  "data/govapp/fold3" \
--bert_model "indobenchmark/indobert-base-p2" \
--model_path "checkpoint/fold3/model_best" \
--batch_size 1 \
--max_seq_len 512

# %%
# !python "evaluate_test.py" \
--test_path  "data/govapp/fold3" \
--bert_model "indobenchmark/indobert-base-p2" \
--model_path "checkpoint/fold3/model_best" \
--batch_size 1 \
--max_seq_len 512

# %% [markdown]
# ### **Fold 4**

# %%
# !python "evaluate.py" \
--test_path  "data/govapp/fold4" \
--bert_model "indobenchmark/indobert-base-p2" \
--model_path "checkpoint/fold4/model_best" \
--batch_size 1 \
--max_seq_len 512

# %%
# !python "evaluate_test.py" \
--test_path  "data/govapp/fold4" \
--bert_model "indobenchmark/indobert-base-p2" \
--model_path "checkpoint/fold4/model_best" \
--batch_size 1 \
--max_seq_len 512

# %% [markdown]
# ### **Fold 5**

# %%
# !python "evaluate.py" \
--test_path  "data/govapp/fold5" \
--bert_model "indobenchmark/indobert-base-p2" \
--model_path "checkpoint/fold5/model_best" \
--batch_size 1 \
--max_seq_len 512

# %%
# !python "evaluate_test.py" \
--test_path  "data/govapp/fold5" \
--bert_model "indobenchmark/indobert-base-p2" \
--model_path "checkpoint/fold5/model_best" \
--batch_size 1 \
--max_seq_len 512
